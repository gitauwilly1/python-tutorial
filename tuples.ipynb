# %%
numbers = [7, 2, 8, 4, 9, 5, 3, 6, 1]
numbers.sort() 
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
numbers = [43, 89, 67, 56, 12]

largest = max(numbers)
print(f"The largest number is: {largest}")
# Out:
# The largest number is: 89

# %%
list1 = [10, 20, 30, 40, 50]

sum_of_list = sum(list1)
print(f"The sum of the list is: {sum_of_list}")
# Out:
# The sum of the list is: 150

# %%
list2 = [23, 45, 67, -10, 23, 50, -10]

removed_duplicates = list(set(list2))
print(f"List with duplicates removed: {removed_duplicates}")
# Out:
# List with duplicates removed: [67, 45, 50, -10, 23]

# %%
list3 = [7, 2, 8, 4, 9, 5, 3, 6, 1]

for num in list3:
    print(num)
    index = list3.index(num)
    print(f"Index of {num}: {index}")
# Out:
# 7
# Index of 7: 0
# 2
# Index of 2: 1
# 8
# Index of 8: 2
# 4
# Index of 4: 3
# 9
# Index of 9: 4
# 5
# Index of 5: 5
# 3
# Index of 3: 6
# 6
# Index of 6: 7
# 1
# Index of 1: 8

# %%
student = ('Mary', 22, 'Grade 12')

name, age, grade = student
print(student)
# Out:
# ('Mary', 22, 'Grade 12')

# %%
operator = ('+', '-', '*', '/')

first_num = int(input("Enter the first number: "))
operator_input = input("Enter the operator (+, -, *, /): ")
second_num = int(input("Enter the second number: "))

if operator_input == '+':
    result = first_num + second_num
    print(f"The result of addition is: {result}")
elif operator_input == '-':
    result = first_num - second_num
    print(f"The result of subtraction is: {result}")
elif operator_input == '*':
    result = first_num * second_num
    print(f"The result of multiplication is: {result}")
elif operator_input == '/':
    result = first_num / second_num
    print(f"The result of division is: {result}")
else:
    print("Invalid operator. Please choose from +, -, *, or /.")
# Out:
# The result of addition is: 13
